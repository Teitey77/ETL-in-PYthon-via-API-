# %%
# The headers dictionary contains additional information to be included in the request, such as authentication tokens or content type

# %% [markdown]
# # COVID COUNTRIES

# %%
import pandas as pd

# %%
import requests


url = "https://covid-193.p.rapidapi.com/countries"

headers = {
	"X-RapidAPI-Key": "a8c714b9b1msh664df4f33c7d1c2p1c378djsnfeb333634802",
	"X-RapidAPI-Host": "covid-193.p.rapidapi.com"
}

response = requests.get(url, headers=headers)



print(response.json())
# Out:
# {'get': 'countries', 'parameters': [], 'errors': [], 'results': 231, 'response': ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla', 'Antigua-and-Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia-and-Herzegovina', 'Botswana', 'Brazil', 'British-Virgin-Islands', 'Brunei', 'Bulgaria', 'Burkina-Faso', 'Burundi', 'Cabo-Verde', 'Cambodia', 'Cameroon', 'Canada', 'CAR', 'Caribbean-Netherlands', 'Cayman-Islands', 'Chad', 'Channel-Islands', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook-Islands', 'Costa-Rica', 'Croatia', 'Cuba', 'Cura&ccedil;ao', 'Cyprus', 'Czechia', 'Denmark', 'Diamond-Princess', 'Djibouti', 'Dominica', 'Dominican-Republic', 'DPRK', 'DRC', 'Ecuador', 'Egypt', 'El-Salvador', 'Equatorial-Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia', 'Faeroe-Islands', 'Falkland-Islands', 'Fiji', 'Finl
# ...

# %%
data = response.json()
data
# Out:
# {'get': 'countries',
#  'parameters': [],
#  'errors': [],
#  'results': 231,
#  'response': ['Afghanistan',
#   'Albania',
#   'Algeria',
#   'Andorra',
#   'Angola',
#   'Anguilla',
#   'Antigua-and-Barbuda',
#   'Argentina',
#   'Armenia',
#   'Aruba',
#   'Australia',
#   'Austria',
#   'Azerbaijan',
#   'Bahamas',
#   'Bahrain',
#   'Bangladesh',
#   'Barbados',
#   'Belarus',
#   'Belgium',
#   'Belize',
#   'Benin',
#   'Bermuda',
#   'Bhutan',
#   'Bolivia',
#   'Bosnia-and-Herzegovina',
#   'Botswana',
#   'Brazil',
#   'British-Virgin-Islands',
#   'Brunei',
#   'Bulgaria',
#   'Burkina-Faso',
#   'Burundi',
#   'Cabo-Verde',
#   'Cambodia',
#   'Cameroon',
#   'Canada',
#   'CAR',
#   'Caribbean-Netherlands',
#   'Cayman-Islands',
#   'Chad',
#   'Channel-Islands',
#   'Chile',
#   'China',
#   'Colombia',
#   'Comoros',
#   'Congo',
#   'Cook-Islands',
#   'Costa-Rica',
#   'Croatia',
#   'Cuba',
#   'Cura&ccedil;ao',
#   'Cyprus',
#   'Czechia',
#   'Denmark',
# ...

# %%
# accessing or examining the elements of interest in the response but is in the json format so you have to pass it
print(data['response'])
# Out:
# ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla', 'Antigua-and-Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia-and-Herzegovina', 'Botswana', 'Brazil', 'British-Virgin-Islands', 'Brunei', 'Bulgaria', 'Burkina-Faso', 'Burundi', 'Cabo-Verde', 'Cambodia', 'Cameroon', 'Canada', 'CAR', 'Caribbean-Netherlands', 'Cayman-Islands', 'Chad', 'Channel-Islands', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook-Islands', 'Costa-Rica', 'Croatia', 'Cuba', 'Cura&ccedil;ao', 'Cyprus', 'Czechia', 'Denmark', 'Diamond-Princess', 'Djibouti', 'Dominica', 'Dominican-Republic', 'DPRK', 'DRC', 'Ecuador', 'Egypt', 'El-Salvador', 'Equatorial-Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia', 'Faeroe-Islands', 'Falkland-Islands', 'Fiji', 'Finland', 'France', 'French-Guiana', 'French-Polynesia', 'Gabon', 'Gambia', 'Georgia'
# ...

# %%
charlist = []
def parse_json_data(response_r): 
    for item in response_r['response']:
        # print item
        #print(item)
        charlist.append(item)
    return charlist

parse_json_data(data)
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antigua-and-Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia-and-Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British-Virgin-Islands',
#  'Brunei',
#  'Bulgaria',
#  'Burkina-Faso',
#  'Burundi',
#  'Cabo-Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'CAR',
#  'Caribbean-Netherlands',
#  'Cayman-Islands',
#  'Chad',
#  'Channel-Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Cook-Islands',
#  'Costa-Rica',
#  'Croatia',
#  'Cuba',
#  'Cura&ccedil;ao',
#  'Cyprus',
#  'Czechia',
#  'Denmark',
#  'Diamond-Princess',
#  'Djibouti',
#  'Dominica',
#  'Dominican-Republic',
#  'DPRK',
#  'DRC',
#  'Ecuador',
#  'Egypt',
#  'El-Salvador',
# ...

# %%
# Efficient way of parsing json data with sample code and dataset

#def parse_json_data(response_r):
#    # Flatten nested JSON data into a DataFrame
#    df = pd.json_normalize(response_r['response'])
#    return df
#
## Sample JSON data
#data = {
#    'response': [
#        {'name': 'John', 'age': 30, 'address': {'city': 'New York', 'country': 'USA'}},
#        {'name': 'Alice', 'age': 25, 'address': {'city': 'Los Angeles', 'country': 'USA'}},
#        {'name': 'Bob', 'age': 35, 'address': {'city': 'Chicago', 'country': 'USA'}}
#    ]
#}
#
## Call the function to parse JSON data
#parsed_df = parse_json_data(data)
#
## Display the DataFrame
#print(parsed_df)

# %%
column_names = ["Country"]
df_countries = pd.DataFrame(charlist, columns=column_names)
df_countries
# Out:
#                Country
# 0          Afghanistan
# 1              Albania
# 2              Algeria
# 3              Andorra
# 4               Angola
# ..                 ...
# 226  Wallis-and-Futuna
# 227     Western-Sahara
# 228              Yemen
# 229             Zambia
# 230           Zimbabwe
#
# [231 rows x 1 columns]

# %% [markdown]
# # STATISTICS COVID

# %%
import requests

url = "https://covid-193.p.rapidapi.com/statistics"

headers = {
	"X-RapidAPI-Key": "a8c714b9b1msh664df4f33c7d1c2p1c378djsnfeb333634802",
	"X-RapidAPI-Host": "covid-193.p.rapidapi.com"
}

response_1 = requests.get(url, headers=headers)

print(response_1.json())
# Out:
# {'get': 'statistics', 'parameters': [], 'errors': [], 'results': 238, 'response': [{'continent': 'Europe', 'country': 'Vatican-City', 'population': 799, 'cases': {'new': None, 'active': 0, 'critical': None, 'recovered': 29, '1M_pop': '36295', 'total': 29}, 'deaths': {'new': None, '1M_pop': None, 'total': None}, 'tests': {'1M_pop': None, 'total': None}, 'day': '2024-04-14', 'time': '2024-04-14T19:30:16+00:00'}, {'continent': 'Africa', 'country': 'Western-Sahara', 'population': 626161, 'cases': {'new': None, 'active': 0, 'critical': None, 'recovered': 9, '1M_pop': '16', 'total': 10}, 'deaths': {'new': None, '1M_pop': '2', 'total': 1}, 'tests': {'1M_pop': None, 'total': None}, 'day': '2024-04-14', 'time': '2024-04-14T19:30:16+00:00'}, {'continent': None, 'country': 'MS-Zaandam', 'population': None, 'cases': {'new': None, 'active': 0, 'critical': None, 'recovered': 7, '1M_pop': None, 'total': 9}, 'deaths': {'new': None, '1M_pop': None, 'total': 2}, 'tests': {'1M_pop': None, 'total': None
# ...

# %%
data_2 = response_1.json()
print(data_2)
print(type(data_2))
# Out:
# {'get': 'statistics', 'parameters': [], 'errors': [], 'results': 238, 'response': [{'continent': 'Europe', 'country': 'Vatican-City', 'population': 799, 'cases': {'new': None, 'active': 0, 'critical': None, 'recovered': 29, '1M_pop': '36295', 'total': 29}, 'deaths': {'new': None, '1M_pop': None, 'total': None}, 'tests': {'1M_pop': None, 'total': None}, 'day': '2024-04-14', 'time': '2024-04-14T19:30:16+00:00'}, {'continent': 'Africa', 'country': 'Western-Sahara', 'population': 626161, 'cases': {'new': None, 'active': 0, 'critical': None, 'recovered': 9, '1M_pop': '16', 'total': 10}, 'deaths': {'new': None, '1M_pop': '2', 'total': 1}, 'tests': {'1M_pop': None, 'total': None}, 'day': '2024-04-14', 'time': '2024-04-14T19:30:16+00:00'}, {'continent': None, 'country': 'MS-Zaandam', 'population': None, 'cases': {'new': None, 'active': 0, 'critical': None, 'recovered': 7, '1M_pop': None, 'total': 9}, 'deaths': {'new': None, '1M_pop': None, 'total': 2}, 'tests': {'1M_pop': None, 'total': None
# ...

# %%
# accessing or examining the elements of interest in the response but is in the json format so you have to parse (change to usable form structure) it
#data_2['response'][0]
data_2['response']
# Out:
# [{'continent': 'Europe',
#   'country': 'Vatican-City',
#   'population': 799,
#   'cases': {'new': None,
#    'active': 0,
#    'critical': None,
#    'recovered': 29,
#    '1M_pop': '36295',
#    'total': 29},
#   'deaths': {'new': None, '1M_pop': None, 'total': None},
#   'tests': {'1M_pop': None, 'total': None},
#   'day': '2024-04-14',
#   'time': '2024-04-14T19:30:16+00:00'},
#  {'continent': 'Africa',
#   'country': 'Western-Sahara',
#   'population': 626161,
#   'cases': {'new': None,
#    'active': 0,
#    'critical': None,
#    'recovered': 9,
#    '1M_pop': '16',
#    'total': 10},
#   'deaths': {'new': None, '1M_pop': '2', 'total': 1},
#   'tests': {'1M_pop': None, 'total': None},
#   'day': '2024-04-14',
#   'time': '2024-04-14T19:30:16+00:00'},
#  {'continent': None,
#   'country': 'MS-Zaandam',
#   'population': None,
#   'cases': {'new': None,
#    'active': 0,
#    'critical': None,
#    'recovered': 7,
#    '1M_pop': None,
#    'total': 9},
# ...

# %%
# Careful with this might be misleading
# use the one above
#pd.DataFrame(data_2['response'][0])
pd.DataFrame(data_2['response'])[['continent', 'country', 'population', 'day', 'time']]
# Out:
#          continent         country    population         day  \
# 0           Europe    Vatican-City  7.990000e+02  2024-04-14
# 1           Africa  Western-Sahara  6.261610e+05  2024-04-14
# 2             None      MS-Zaandam           NaN  2024-04-14
# 3             Asia           China  1.448471e+09  2024-04-14
# 4           Africa    Saint-Helena  6.115000e+03  2024-04-14
# ..             ...             ...           ...         ...
# 233  South-America   South-America           NaN  2024-04-14
# 234  North-America   North-America           NaN  2024-04-14
# 235           Asia            Asia           NaN  2024-04-14
# 236         Europe          Europe           NaN  2024-04-14
# 237            All             All           NaN  2024-04-14
#
#                           time
# 0    2024-04-14T19:30:16+00:00
# 1    2024-04-14T19:30:16+00:00
# 2    2024-04-14T19:30:16+00:00
# 3    2024-04-14T19:30:16+00:00
# 4    2024-04-14T19:30:15+00:00
# ..                         ...
# ...

# %%
# Out:
# [{'Continent': 'Europe', 'Country': 'Vatican-City', 'Population': 799, 'Day': '2024-04-14', 'Time': '2024-04-14T19:30:16+00:00', 'new': None, 'active': 0, 'critical': None, 'recovered': 29, '1M_pop': '36295', 'total': 29}, {'Continent': 'Africa', 'Country': 'Western-Sahara', 'Population': 626161, 'Day': '2024-04-14', 'Time': '2024-04-14T19:30:16+00:00', 'new': None, 'active': 0, 'critical': None, 'recovered': 9, '1M_pop': '16', 'total': 10}, {'Continent': None, 'Country': 'MS-Zaandam', 'Population': None, 'Day': '2024-04-14', 'Time': '2024-04-14T19:30:16+00:00', 'new': None, 'active': 0, 'critical': None, 'recovered': 7, '1M_pop': None, 'total': 9}, {'Continent': 'Asia', 'Country': 'China', 'Population': 1448471400, 'Day': '2024-04-14', 'Time': '2024-04-14T19:30:16+00:00', 'new': None, 'active': 118977, 'critical': None, 'recovered': 379053, '1M_pop': '347', 'total': 503302}, {'Continent': 'Africa', 'Country': 'Saint-Helena', 'Population': 6115, 'Day': '2024-04-14', 'Time': '2024-04-
# ...

# %%
# METHOD 1

dict_1 = data_2['response']
#print(dict_1)

# Initialize an empty list to store the processed data
list_to_store_json_dataset_1 = []


def parse_json_data_all_columns(json_data):

    
    # Loop through each JSON object
    for item in dict_1:
        processed_data = {
        'Continent': item['continent'],
        'Country': item['country'],
        'Population': item['population'],
        'Day': item['day'],
        'Time': item['time']
    }  
    # Access and process data for 'cases' dictionary
        # Accessing all cases data
        cases = item['cases']
        for case_key, case_value in cases.items():
            processed_data[f'case.{case_key}'] = case_value
            
        deathss = item['deaths']
        for death_key, death_value in deathss.items():
            processed_data[f'deaths.{death_key}'] = case_value
            
        testss = item['tests']
        for test_key, test_value in testss.items():
            processed_data[f'test.{test_key}'] = test_value
        
        list_to_store_json_dataset_1.append(processed_data)
        #list_to_store_json_dataset_1.append(i)
    return list_to_store_json_dataset_1 

parse_json_data_all_columns(list_to_store_json_dataset_1)

df = pd.DataFrame(list_to_store_json_dataset_1)
df.info()







  #'tests': {'1M_pop': None, 'total': None},
  #'day': '2024-04-14',
  #'time': '2024-04-14T19:30:16+00:00'},
#
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Continent       236 non-null    object
#  1   Country         238 non-null    object
#  2   Population      229 non-null    float64
#  3   Day             238 non-null    object
#  4   Time            238 non-null    object
#  5   case.new        45 non-null     object
#  6   case.active     191 non-null    float64
#  7   case.critical   59 non-null     float64
#  8   case.recovered  190 non-null    float64
#  9   case.1M_pop     230 non-null    object
#  10  case.total      238 non-null    int64
#  11  deaths.new      238 non-null    int64
#  12  deaths.1M_pop   238 non-null    int64
#  13  deaths.total    238 non-null    int64
#  14  test.1M_pop     213 non-null    object
#  15  test.total      213 non-null    float64
# dtypes: float64(5), int64(4), object(7)
# ...

# %%
# accessing or examining the elements of interest in the response but is in the json format so you have to parse (change to usable form structure) it
first_item_in_dataset_index0 = data_2['response'][0]
first_item_in_dataset_index0

#second_item_in_dataset_index1 = data_2['response'][1]
#print(second_item_in_dataset_index1)
# Out:
# {'continent': 'Europe',
#  'country': 'Vatican-City',
#  'population': 799,
#  'cases': {'new': None,
#   'active': 0,
#   'critical': None,
#   'recovered': 29,
#   '1M_pop': '36295',
#   'total': 29},
#  'deaths': {'new': None, '1M_pop': None, 'total': None},
#  'tests': {'1M_pop': None, 'total': None},
#  'day': '2024-04-14',
#  'time': '2024-04-14T19:30:16+00:00'}

# %%
# Store the json data in a list. This removes it from the json file and move it into a lits


#print(data_2['response'])
list_to_store_json_dataset = []
def parse_json_data(json_data):
    for i in data_2['response']:
        #print(i)
        list_to_store_json_dataset.append(i)
    return list_to_store_json_dataset

parse_json_data(data_2)
# Out:
# [{'continent': 'Europe',
#   'country': 'Vatican-City',
#   'population': 799,
#   'cases': {'new': None,
#    'active': 0,
#    'critical': None,
#    'recovered': 29,
#    '1M_pop': '36295',
#    'total': 29},
#   'deaths': {'new': None, '1M_pop': None, 'total': None},
#   'tests': {'1M_pop': None, 'total': None},
#   'day': '2024-04-14',
#   'time': '2024-04-14T19:30:16+00:00'},
#  {'continent': 'Africa',
#   'country': 'Western-Sahara',
#   'population': 626161,
#   'cases': {'new': None,
#    'active': 0,
#    'critical': None,
#    'recovered': 9,
#    '1M_pop': '16',
#    'total': 10},
#   'deaths': {'new': None, '1M_pop': '2', 'total': 1},
#   'tests': {'1M_pop': None, 'total': None},
#   'day': '2024-04-14',
#   'time': '2024-04-14T19:30:16+00:00'},
#  {'continent': None,
#   'country': 'MS-Zaandam',
#   'population': None,
#   'cases': {'new': None,
#    'active': 0,
#    'critical': None,
#    'recovered': 7,
#    '1M_pop': None,
#    'total': 9},
# ...

# %%
# Out:
# JSON

# %%
# Out:
# <class 'list'>
# ...

# %%
# data is now store in a list
print(type(list_to_store_json_dataset)) # This is a list
print(list_to_store_json_dataset)


# Flatten the JSON data into a DataFrame (parsing)
df_3 = pd.json_normalize(list_to_store_json_dataset)
df_3
# Out:
#          continent         country    population         day  \
# 0           Europe    Vatican-City  7.990000e+02  2024-04-14
# 1           Africa  Western-Sahara  6.261610e+05  2024-04-14
# 2             None      MS-Zaandam           NaN  2024-04-14
# 3             Asia           China  1.448471e+09  2024-04-14
# 4           Africa    Saint-Helena  6.115000e+03  2024-04-14
# ..             ...             ...           ...         ...
# 233  South-America   South-America           NaN  2024-04-14
# 234  North-America   North-America           NaN  2024-04-14
# 235           Asia            Asia           NaN  2024-04-14
# 236         Europe          Europe           NaN  2024-04-14
# 237            All             All           NaN  2024-04-14
#
#                           time cases.new  cases.active  cases.critical  \
# 0    2024-04-14T19:30:16+00:00      None           0.0             NaN
# 1    2024-04-14T19:30:16+00:00      None           0.0             NaN
# ...

# %%
# cehcking the file type so we know to parse it
def check_data_type(data):
    if isinstance(data, dict):
        print("Data is in JSON format.")
    elif isinstance(data, list):
        print("Data is stored in a regular list.")
    else:
        print("Data type is neither JSON nor a regular list.")
        
check_data_type(data_2)
check_data_type(list_to_store_json_dataset)
# Out:
# Data is in JSON format.
# Data is stored in a regular list.

# %%
dictionary = {"a":1, "B":2, "c":3}
